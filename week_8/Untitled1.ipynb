# %%
#project 3

def qualifications():
    import pandas as pd
    print('Sorry you do not qualify')
    name = input('Enter name: ')
    age = input('Enter age: ')
    age = data[name.title()]
    df = pd.DataFrame(data)
    df.to_csv('admitted.csv')
    print('success')
    return

data = {}

jambscore = int(input('Enter JAMB score: '))
if jambscore < 230:
    qualifications()
    elif jambscore >= 230:
        credit = input('Did you get at least 5 credits in the key subjects? yes/no ')
        if credit == 'yes'.upper():
        interview = input('Did you pass the interview? ')
        if interview = yes.upper():
