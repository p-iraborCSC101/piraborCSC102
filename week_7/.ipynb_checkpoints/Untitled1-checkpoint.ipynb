# %%
#project 3 
import pandas as pd

print('Welcome!')

admitted = []
not_admitted = []

def qualifications():
    jamb_score = int(input('Enter jamb score: '))
    key_subjects = input('Did you get at least 5 credits in the key subjects? [yes or no] ').upper()
    interview = input('Did you pass the interview? [yes or no] ').upper()
    
    admiited = {}
    if jamb_score >= 230 and key_subjects == 'YES' and interview == 'YES':
        print('Congratulations!')
        name = input('Enter your name: ')
        age = input('Enter your age: ')
        course = input('Enter course: ')
        adm = {'Name' : name, 'Age' : age, 'Course' : course}
        admitted.append(adm)
        df = pd.DataFrame(admitted)
        df.to_csv('admitted.csv')
        
    else:
        print('Sorry you do not qualify!')
        name = input('Enter your name: ')
        age = input('Enter your age: ')
        course = input('Enter course: ')
        not_adm = {'Name' : name, 'Age' : age, 'Course' : course}
        not_admitted.append(not_adm)
        df = pd.DataFrame(not_admitted)
        df.to_csv('not_admittted.csv')
        
        
        return
        

qualifications()   
print('Success')
# Out:
# Welcome!
# Enter jamb score: 230
# Did you get at least 5 credits in the key subjects? [yes or no] yes
# Did you pass the interview? [yes or no] yes
# Congratulations!
# Enter your name: Paula
# Enter your age: 16
# Enter course: ISMS
# Success

# %%
#project 2
location = input('Enter your location (Ibeju-Lekki or Epe): ').upper()
weight = int(input('Enter package weight: '))

if location == 'IBEJU-LEKKI' and weight >= 10:
    print('Price is 2000')
elif location == 'IJEBU-LEKKI' and weight < 10:
    print('Price is 1500')
elif location == 'EPE' and weight >= 10:
    print('Price is 5000')
else:
    print('Price is 4000')
# Out:
# Enter your location (Ibeju-Lekki or Epe): epe
# Enter package weight: 9
# Price is 4000

# %%
#project 1
import pandas as pd
name = input('Enter name: ').lower()
department = input('Enter department: ').lower()
data = pd.read_csv('jt-ventures.csv')
data

if name ==
# Out:
# Enter name: p
# Enter department: d
#      S/N           SURNAME     FIRST NAME      DEPARTMENT  Unnamed: 4
# 0    1.0          ADENIRAN  Oluwatamilore       Logistics         NaN
# 1    2.0           ADEWUMI        Ayomide      Accounting         NaN
# 2    3.0       ADOH-AJAGBE          Oshim        Delivery         NaN
# 3    4.0  AGBAKURU- \NWOGU    Chukwunonye      Accounting         NaN
# 4    5.0         AGBAKWURU     Chiemeziem       Logistics         NaN
# 5    6.0            AKINDE   Oluwatimehin      Accounting         NaN
# 6    7.0            ARNIKA          Osose       Logistics         NaN
# 7    8.0            ATELLY         Daniel        Delivery         NaN
# 8    9.0             AZOGU      Onyekachi        Delivery         NaN
# 9   10.0            BETURE         Shalom        Delivery         NaN
# 10  11.0          CHUKWUMA           Nedi       Logistics         NaN
# 11  12.0               EBI      Stephanie      Accounting         NaN
# ...
