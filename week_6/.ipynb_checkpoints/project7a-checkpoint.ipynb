# %%
# top apps in google play
import pandas as pd

google = pd.read_csv("top_apps_in_google_play.zip")

# displaying the first 7 rows
df = google.head(8)

df
# Out:
#    Unnamed: 0                          App Name  \
# 0           1              Google Play services
# 1           2                           YouTube
# 2           3                            Google
# 3           4  Google Maps - Navigate & Explore
# 4           5             Google Text-to-Speech
# 5           6      Google Chrome: Fast & Secure
# 6           7                             Gmail
# 7           8       Android Accessibility Suite
#
#                                     App Id                 Category  \
# 0                   com.google.android.gms                    Tools
# 1               com.google.android.youtube  Video Players & Editors
# 2  com.google.android.googlequicksearchbox                    Tools
# 3             com.google.android.apps.maps           Travel & Local
# 4                   com.google.android.tts                    Tools
# 5                       com.android.chrome            Communication
# ...

# %%
# top apps in google play
import pandas as pd

google = pd.read_csv("top_apps_in_google_play.zip")

# displaying one row and header
df = google.head(1)

df
# Out:
#    Unnamed: 0              App Name                  App Id Category  \
# 0           1  Google Play services  com.google.android.gms    Tools
#
#   Developer Id                                  Developer Website  \
# 0   Google LLC  https://developers.google.com/android/google-p...
#
#         Developer Email Content Rating  Ad Supported  In App Purchases
# 0  apps-help@google.com       Everyone         False             False

# %%
# top apps in google play
import pandas as pd

google = pd.read_csv("top_apps_in_google_play.zip")


# displaying the fisrt 3 columns
df[['App Name', 'App Id', 'Category']]
# Out:
#                            App Name                                   App Id  \
# 0              Google Play services                   com.google.android.gms
# 1                           YouTube               com.google.android.youtube
# 2                            Google  com.google.android.googlequicksearchbox
# 3  Google Maps - Navigate & Explore             com.google.android.apps.maps
# 4             Google Text-to-Speech                   com.google.android.tts
# 5      Google Chrome: Fast & Secure                       com.android.chrome
# 6                             Gmail                    com.google.android.gm
# 7       Android Accessibility Suite       com.google.android.marvin.talkback
#
#                   Category
# 0                    Tools
# 1  Video Players & Editors
# 2                    Tools
# 3           Travel & Local
# 4                    Tools
# 5            Communication
# 6            Communication
# 7                    Tools

# %%
# Cryptocurrency Predict Artificial Intelligence V3
import pandas as pd
 
# displaying the first 7 rows
crypto = pd.read_csv("crypto.csv")

df = crypto.head(8)

df
# Out:
#         Date    Price     Open     High      Low     Vol. Change %
# 0  25-Mar-22  44331.0  44013.0  45112.0  43622.0  494.09M    0.72%
# 1  24-Mar-22  44013.0  42911.0  44251.0  42658.0  491.66M    2.57%
# 2  23-Mar-22  42912.0  42373.0  43027.0  41795.0  433.96M    1.27%
# 3  22-Mar-22  42373.0  41022.0  43327.9  40893.0  537.06M    3.29%
# 4  21-Mar-22  41022.0  41282.0  41532.0  40530.0  406.62M   -0.62%
# 5  20-Mar-22  41276.0  42241.0  42301.0  40922.0  308.45M   -2.27%
# 6  19-Mar-22  42233.0  41768.0  42386.0  41529.6  224.59M    1.11%
# 7  18-Mar-22  41767.8  40914.6  42308.4  40234.8    2.31B    2.08%

# %%
# Cryptocurrency Predict Artificial Intelligence V3
import pandas as pd
 
# displaying the first 3 columns
crypto = pd.read_csv("crypto.csv")

df[['Date','Price','Open']]
# Out:
#         Date    Price     Open
# 0  25-Mar-22  44331.0  44013.0
# 1  24-Mar-22  44013.0  42911.0
# 2  23-Mar-22  42912.0  42373.0
# 3  22-Mar-22  42373.0  41022.0
# 4  21-Mar-22  41022.0  41282.0
# 5  20-Mar-22  41276.0  42241.0
# 6  19-Mar-22  42233.0  41768.0
# 7  18-Mar-22  41767.8  40914.6

# %%
# Cryptocurrency Predict Artificial Intelligence V3
import pandas as pd
 
# displaying the one row and header
crypto = pd.read_csv("crypto.csv")

df = crypto.head(1)

df
# Out:
#         Date    Price     Open     High      Low     Vol. Change %
# 0  25-Mar-22  44331.0  44013.0  45112.0  43622.0  494.09M    0.72%

# %%
# Programming Laungages and File Format Detection
import pandas as pd

# displaying the first 7 rows
program = pd.read_csv("programs.csv")

df = program.head(8)

df
# Out:
#    id           file_path  file_size  line_count extension  language
# 0   1  Markdown/000001.md      34784         572        md  Markdown
# 1   2    XML/000002.props       3013          44     props       XML
# 2   3     Text/000003.txt       1076          21       txt      Text
# 3   4  Markdown/000004.md       8105          84        md  Markdown
# 4   5  Markdown/000005.md       2763          41        md  Markdown
# 5   6  Markdown/000006.md       2030          32        md  Markdown
# 6   7    JSON/000007.json        591          19      json      JSON
# 7   8    JSON/000008.json        183          11      json      JSON

# %%
# Programming Laungages and File Format Detection
import pandas as pd

# displaying the first 3 columns
program = pd.read_csv("programs.csv")

df[['id','file_path','file_size']]
# Out:
#    id           file_path  file_size
# 0   1  Markdown/000001.md      34784
# 1   2    XML/000002.props       3013
# 2   3     Text/000003.txt       1076
# 3   4  Markdown/000004.md       8105
# 4   5  Markdown/000005.md       2763
# 5   6  Markdown/000006.md       2030
# 6   7    JSON/000007.json        591
# 7   8    JSON/000008.json        183

# %%
# Programming Laungages and File Format Detection
import pandas as pd

# displaying the one row and header
program = pd.read_csv("programs.csv")

df = program.head(1)

df
# Out:
#    id           file_path  file_size  line_count extension  language
# 0   1  Markdown/000001.md      34784         572        md  Markdown
